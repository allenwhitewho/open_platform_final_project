# %%
import requests
from bs4 import BeautifulSoup
import time
import random

# 使用一般 session，不用 requests_cache
session = requests.Session()

# 基本 headers
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Referer": "https://www.books.com.tw/",
    "Accept-Language": "zh-TW,zh;q=0.9"
}
session.headers.update(headers)

# 防止被封機制
def safe_sleep():
    t = random.uniform(3, 7)
    print(f"⏳ 等待 {t:.2f} 秒...")
    time.sleep(t)

# %%
# 分類抓取函式
def get_category(book_url, retries=3):
    for attempt in range(retries):
        try:
            safe_sleep()
            res = session.get(book_url, timeout=15)
            res.raise_for_status()
            html = res.text

            if "限制級商品" in html or "18歲以上會員" in html:
                return "限制級商品（需登入）"
            if "您的連線暫時異常" in html or "Connection is temporarily unavailable" in html:
                return "連線暫時異常"

            soup = BeautifulSoup(html, "html.parser")
            breadcrumb = soup.select("ul#breadcrumb-trail li a")
            if len(breadcrumb) >= 3:
                return breadcrumb[2].text.strip()
            else:
                return "未知分類"
        except Exception as e:
            time.sleep(60)
    return "分類讀取失敗"

# %%
# 先測試個別連結是否分類正確
print(get_category("https://www.books.com.tw/products/0011016503?loc=P_0001_015"))
print(get_category("https://www.books.com.tw/products/0011015621?loc=P_0001_016"))
# Out:
# ⏳ 等待 6.60 秒...
# 限制級商品（需登入）
# ⏳ 等待 6.59 秒...
# 生活風格

# %%
category_count = {}

# 抓排行榜頁
url = "https://www.books.com.tw/web/sys_tdrntb/books/"
res = session.get(url)
soup = BeautifulSoup(res.text, "html.parser")
books = soup.select("li.item")

# 開始爬蟲
seen_links = set()
idx = 1
error_count = 0

import csv

# 建立一個清單來存每本書的資料
book_data = []

for book in books[23:73]:
    title_tag = book.select_one("h4 > a")
    if not title_tag:
        continue

    original_link = title_tag["href"]
    book_id = original_link.split("/products/")[-1].split("?")[0]
    link = f"https://www.books.com.tw/products/{book_id}/{idx}"

    if link in seen_links:
        continue
    seen_links.add(link)

    title = title_tag.text.strip()
    author_tag = book.select_one("ul.msg li:nth-of-type(1) a")
    author = author_tag.text.strip() if author_tag else "未知作者"

    price_tag = book.select_one("ul.msg li.price_a")
    price = "未知價格"
    if price_tag:
        price_text = price_tag.get_text(strip=True)
        if "元" in price_text:
            price = price_text.split("元")[0].split("折")[-1] + "元"

    category = get_category(link)

    if category not in category_count:
        category_count[category] = 1
    else:
        category_count[category] += 1

    if "異常" in category or "失敗" in category:
        error_count += 1
    else:
        error_count = 0

    if error_count >= 1:
        print("⚠️ 連續出錯超過 5 次，暫停 60 秒...")
        time.sleep(60)
        error_count = 0
        category = get_category(link)

    print(f"{idx}. 書名: {title}")
    print(f"    連結: {link}")
    print(f"    作者: {author}")
    print(f"    價格: {price}")
    print(f"    分類: {category}")
    idx += 1

    # 把這筆資料加入 list
    book_data.append([title, author, price, category, link])
# Out:
# ⏳ 等待 5.51 秒...
# 1. 書名: 世界上最透明的故事（日本出版界話題作，只有紙本書可以體驗的感動）
#     連結: https://www.books.com.tw/products/0011001466/1
#     作者: 杉井光
#     價格: 284元
#     分類: 文學小說
# ⏳ 等待 5.97 秒...
# 2. 書名: 旅者健康守護人
#     連結: https://www.books.com.tw/products/0011017700/2
#     作者: 未知作者
#     價格: 379元
#     分類: 醫療保健
# ⏳ 等待 3.12 秒...
# 3. 書名: 【中小學生必讀】好好說話超圖解：「換句話說」就能建立好人緣
#     連結: https://www.books.com.tw/products/0011007253/3
#     作者: 齋藤孝
#     價格: 331元
#     分類: 童書/青少年文學
# ⏳ 等待 5.11 秒...
# 4. 書名: 納瓦爾寶典珍藏版：從白手起家到財務自由，矽谷傳奇創投家的投資哲學與人生智慧
#     連結: https://www.books.com.tw/products/0011012422/4
#     作者: 艾瑞克．喬根森
#     價格: 355元
#     分類: 商業理財
# ⏳ 等待 5.68 秒...
# 5. 書名: 想見妮‧Nicole妮可寫真書★限量盒裝版【博客來獨家】
#     連結: https://www.books.com.tw/products/0011017403/5
#     作者: 妮可Nicole
#     價格: 優惠價：1200元
#     分類: 影視偶像
# ⏳ 等待 6.34 秒...
# 6. 書名: 巫師霍爾三部曲（世界奇幻獎終身成就獎得主，生涯代表作）隨書附贈郵票造型書籤卡
#     連結: https://www.books.com.tw/products/0010974702/6
#     作者: 黛安娜．韋恩．瓊斯
#     價格: 950元
#     分類: 文學小說
# ⏳ 等待 4.96 秒...
# 7. 書名: 養心2：泥魔妖的誘惑（首批附贈作者印簽金句扉頁及五悔角色卡）
#     連結: https://www.books.com.tw/products/0011016959/7
#     作者: 陳郁如
#     價格: 331元
#     分類: 童書/青少年文學
# ⏳ 等待 4.68 秒...
# 8. 書名: 如果歷史是一群喵(15)：大清風雲篇【萌貓漫畫學歷史】
#     連結: https://www.books.com.tw/products/0011017641/8
#     作者: 肥志
#     價格: 387元
#     分類: 人文社科
# ⏳ 等待 5.84 秒...
# 9. 書名: 酸種麵包原來如此：從零開始～祖祖的自養酵母烘焙筆記
#     連結: https://www.books.com.tw/products/0011017248/9
#     作者: 唐子浩
#     價格: 458元
#     分類: 飲食
# ⏳ 等待 5.80 秒...
# 10. 書名: 臺灣漫遊錄
#     連結: https://www.books.com.tw/products/0010852315/10
#     作者: 楊双子
#     價格: 300元
#     分類: 文學小說
# ⏳ 等待 6.22 秒...
# 11. 書名: 權證小哥短線終極戰法：4大策略 ✖ 6種工具 ✖ 68個實戰案例，手把手教你賺
#     連結: https://www.books.com.tw/products/0011014572/11
#     作者: 權證小哥
#     價格: 379元
#     分類: 商業理財
# ⏳ 等待 4.91 秒...
# 12. 書名: 納瓦爾寶典：從白手起家到財務自由， 矽谷傳奇創投家的投資哲學與人生智慧
#     連結: https://www.books.com.tw/products/0010977461/12
#     作者: 艾瑞克．喬根森
#     價格: 355元
#     分類: 商業理財
# ⏳ 等待 4.63 秒...
# 13. 書名: 全新制怪物講師教學團隊的TOEIC多益5回全真模擬試題+解析【修訂版】（2書＋1CD＋文法教學影片＋「Youtor App」內含VRP虛擬點讀筆＋防水書套）
#     連結: https://www.books.com.tw/products/0010903540/13
#     作者: 林政翰,怪物講師教學團隊（台灣）
#     價格: 473元
#     分類: 語言學習
# ⏳ 等待 5.92 秒...
# 14. 書名: 戰爭下的平民生存手冊：懂這些，才能撐過黃金48小時【關鍵時刻救你，也救家人】(附緊急避難檢查卡)
#     連結: https://www.books.com.tw/products/0010954819/14
#     作者: 邱世卿
#     價格: 355元
#     分類: 人文社科
# ⏳ 等待 5.41 秒...
# 15. 書名: 認知破局【限量博客來獨家書衣＋2025破局曆】：解題思路比答案本身重要一萬倍
#     連結: https://www.books.com.tw/products/0010997788/15
#     作者: 張琦
#     價格: 331元
#     分類: 商業理財
# ⏳ 等待 3.81 秒...
# 16. 書名: Minecraft漫畫~探索世界的盡頭~ 6
#     連結: https://www.books.com.tw/products/0011017995/16
#     作者: 瀬戸カズヨシ
#     價格: 197元
#     分類: 童書/青少年文學
# ⏳ 等待 5.56 秒...
# 17. 書名: Minecraft漫畫~探索世界的盡頭~ 4
#     連結: https://www.books.com.tw/products/0011017991/17
#     作者: 瀬戸カズヨシ
#     價格: 197元
#     分類: 童書/青少年文學
# ⏳ 等待 6.81 秒...
# 18. 書名: 日文自學ALL IN ONE全攻略【初級】(附100分鐘老師真人教學文法影片+100分鐘單字學習影片+50音筆順練習表+「Youtor App」內含VRP虛擬點讀筆)
#     連結: https://www.books.com.tw/products/0010991568/18
#     作者: 金子祐己Yumi
#     價格: 354元
#     分類: 語言學習
# ⏳ 等待 4.65 秒...
# 19. 書名: 別對每件事都有反應：淡泊一點也無妨， 活出快意人生的99個禪練習！
#     連結: https://www.books.com.tw/products/0010945925/19
#     作者: 枡野俊明
#     價格: 260元
#     分類: 心理勵志
# ⏳ 等待 6.85 秒...
# 20. 書名: 長女病：我們不是天生愛扛責任，台灣跨世代女兒的故事
#     連結: https://www.books.com.tw/products/0011017053/20
#     作者: 張慧慈（小花媽）
#     價格: 355元
#     分類: 人文社科
# ⏳ 等待 6.10 秒...
# 21. 書名: 人生就是一次次的得到與放下
#     連結: https://www.books.com.tw/products/0011015062/21
#     作者: 黃大米
#     價格: 292元
#     分類: 心理勵志
# ⏳ 等待 4.57 秒...
# 22. 書名: 被討厭的勇氣：自我啟發之父「阿德勒」的教導
#     連結: https://www.books.com.tw/products/0010653153/22
#     作者: 岸見一郎,古賀史健
#     價格: 237元
#     分類: 心理勵志
# ⏳ 等待 6.24 秒...
# 23. 書名: Minecraft漫畫~探索世界的盡頭~ 5
#     連結: https://www.books.com.tw/products/0011017993/23
#     作者: 瀬戸カズヨシ
#     價格: 197元
#     分類: 童書/青少年文學
# ⏳ 等待 5.20 秒...
# 24. 書名: 腎臟求救中：真希望40歲之前洪永祥醫師就告訴我這些事
#     連結: https://www.books.com.tw/products/0011006704/24
#     作者: 洪永祥
#     價格: 379元
#     分類: 醫療保健
# ⏳ 等待 3.59 秒...
# 25. 書名: 蛤蟆先生去看心理師（暢銷300萬冊！英國心理諮商經典，附《蛤蟆先生勇氣藏書卡》組）
#     連結: https://www.books.com.tw/products/0010914794/25
#     作者: 羅伯．狄保德
#     價格: 316元
#     分類: 心理勵志
# ⏳ 等待 6.45 秒...
# 26. 書名: 世界盡頭的咖啡館：這一生，我為何而存在？（全球每19秒售出1本！療癒千萬人的暢銷經典，定位人生的神奇之書）
#     連結: https://www.books.com.tw/products/0011014199/26
#     作者: 約翰‧史崔勒基
#     價格: 395元
#     分類: 心理勵志
# ⏳ 等待 4.94 秒...
# 27. 書名: 世界上最神奇的24堂課：全世界唯一一本，因為揭露「致富秘訣」而被查禁的書！
#     連結: https://www.books.com.tw/products/0010959973/27
#     作者: 查爾斯‧哈奈爾
#     價格: 237元
#     分類: 商業理財
# ⏳ 等待 3.90 秒...
# 28. 書名: 課本中消失的文學生命與千古追求：一○八課綱中的文化缺席
#     連結: https://www.books.com.tw/products/0011011085/28
#     作者: 區桂芝
#     價格: 284元
#     分類: 文學小說
# ⏳ 等待 5.92 秒...
# 29. 書名: 你的人生，他們六個說了算！：決定你一生的六種物質
#     連結: https://www.books.com.tw/products/0011009311/29
#     作者: 大衛．JP．菲利浦斯
#     價格: 284元
#     分類: 心理勵志
# ⏳ 等待 4.75 秒...
# 30. 書名: 翻轉你的期貨交易：何毅里長伯突破瓶頸的五個黄金法則
#     連結: https://www.books.com.tw/products/0011016500/30
#     作者: 何毅里長伯
#     價格: 394元
#     分類: 商業理財
# ⏳ 等待 3.40 秒...
# 31. 書名: 第四翼【戰龍系列1】
#     連結: https://www.books.com.tw/products/0011016503/31
#     作者: 瑞貝卡・亞羅斯
#     價格: 592元
#     分類: 限制級商品（需登入）
# ⏳ 等待 5.84 秒...
# 32. 書名: 從低谷突破：40年精神科權威史塔茲的療癒之道
#     連結: https://www.books.com.tw/products/0011016348/32
#     作者: 菲爾．史塔茲
#     價格: 355元
#     分類: 心理勵志
# ⏳ 等待 5.54 秒...
# 33. 書名: 失控的焦慮世代：手機餵養的世代，如何面對心理疾病的瘟疫
#     連結: https://www.books.com.tw/products/0011006606/33
#     作者: 強納森．海德特
#     價格: 360元
#     分類: 人文社科
# ⏳ 等待 6.09 秒...
# 34. 書名: 寂靜的春天：瑞秋．卡森逝世60周年紀念版
#     連結: https://www.books.com.tw/products/0010999217/34
#     作者: 瑞秋．卡森
#     價格: 200元
#     分類: 自然科普
# ⏳ 等待 4.40 秒...
# 35. 書名: 別對每件事都有反應【2025限量暢銷特典版】：淡泊一點也無妨，活出快意人生的99個禪練習！
#     連結: https://www.books.com.tw/products/0011008307/35
#     作者: 枡野俊明
#     價格: 260元
#     分類: 心理勵志
# ⏳ 等待 3.15 秒...
# 36. 書名: 這不是一本畫畫書：每日5分鐘，Hank陪你畫畫專注練習【限量】（附贈「阿貓阿狗」防水貼紙、「有貓也有鴨」明信片組）
#     連結: https://www.books.com.tw/products/0011016625/36
#     作者: Hank
#     價格: 379元
#     分類: 藝術設計
# ⏳ 等待 6.72 秒...
# 37. 書名: 希臘羅馬神話漫畫29：浩劫重生
#     連結: https://www.books.com.tw/products/0011016355/37
#     作者: 朴始連
#     價格: 308元
#     分類: 童書/青少年文學
# ⏳ 等待 4.92 秒...
# 38. 書名: 媽媽，為什麼要快一點？（時間觀念＋親子關係＋共讀繪本）
#     連結: https://www.books.com.tw/products/0011009562/38
#     作者: 中川宏貴
#     價格: 300元
#     分類: 童書/青少年文學
# ⏳ 等待 4.16 秒...
# 39. 書名: 壽司去旅行（田中達也的微型世界）
#     連結: https://www.books.com.tw/products/0011009682/39
#     作者: 田中達也
#     價格: 252元
#     分類: 童書/青少年文學
# ⏳ 等待 4.44 秒...
# 40. 書名: 情緒大飯店
#     連結: https://www.books.com.tw/products/0010985365/40
#     作者: 莉迪亞．布蘭科維琪
#     價格: 276元
#     分類: 童書/青少年文學
# ⏳ 等待 4.79 秒...
# 41. 書名: 持續買進：資料科學家的投資終極解答，存錢及致富的實證方法
#     連結: https://www.books.com.tw/products/0010957881/41
#     作者: 尼克．馬朱利
#     價格: 316元
#     分類: 商業理財
# ⏳ 等待 6.52 秒...
# 42. 書名: 原子習慣：細微改變帶來巨大成就的實證法則
#     連結: https://www.books.com.tw/products/0010822522/42
#     作者: 詹姆斯‧克利爾
#     價格: 260元
#     分類: 商業理財
# ⏳ 等待 4.42 秒...
# 43. 書名: 低年級國小國語作業簿
#     連結: https://www.books.com.tw/products/0010983742/43
#     作者: 世一文化編輯群
#     價格: 23元
#     分類: 國中小參考書
# ⏳ 等待 3.70 秒...
# 44. 書名: 國小國語作業簿：中高年級
#     連結: https://www.books.com.tw/products/0010969685/44
#     作者: 世一文化編輯群
#     價格: 23元
#     分類: 國中小參考書
# ⏳ 等待 5.20 秒...
# 45. 書名: 第二堂人生國文課：以文字為燈，一場國文課的溫柔革命【作者限量親簽+燙金書籤】
#     連結: https://www.books.com.tw/products/0011016984/45
#     作者: 羊咩老師
#     價格: 300元
#     分類: 文學小說
# ⏳ 等待 3.11 秒...
# 46. 書名: 自我對畫：給所有大人心裡的小孩
#     連結: https://www.books.com.tw/products/0011015077/46
#     作者: 程予希
#     價格: 379元
#     分類: 影視偶像
# ⏳ 等待 5.63 秒...
# 47. 書名: 敬畏神，讓你無所畏懼：6 週領受改變你一生的智慧
#     連結: https://www.books.com.tw/products/0010991737/47
#     作者: 約翰・畢維爾
#     價格: 322元
#     分類: 宗教命理
# ⏳ 等待 3.45 秒...
# 48. 書名: 推理(286)：域
#     連結: https://www.books.com.tw/products/0011010571/48
#     作者: 台灣犯罪作家聯會
#     價格: 316元
#     分類: 文學小說
# ⏳ 等待 3.33 秒...
# 49. 書名: 經濟評論家父親給兒子的一封信：關於金錢、人生與幸福
#     連結: https://www.books.com.tw/products/0011014595/49
#     作者: 山崎元
#     價格: 276元
#     分類: 商業理財
# ⏳ 等待 4.09 秒...
# 50. 書名: 為什麼大人常常說「不行」？：親子溝通對話指南
#     連結: https://www.books.com.tw/products/0011014580/50
#     作者: 陳培娟
#     價格: 276元
#     分類: 童書/青少年文學

# %%
# 寫入 CSV 檔案
with open("static.csv", "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f)
    writer.writerow(["書名", "作者", "價格", "分類", "連結"])
    writer.writerows(book_data)

# %%
print("\n📊 分類統計結果（依出現次數排序）：")
for cat, count in sorted(category_count.items(), key=lambda x: x[1], reverse=True):
    print(f"分類「{cat}」出現次數：{count}")
# Out:
# 📊 分類統計結果（依出現次數排序）：
# 分類「童書/青少年文學」出現次數：10
# 分類「商業理財」出現次數：9
# 分類「心理勵志」出現次數：8
# 分類「文學小說」出現次數：6
# 分類「人文社科」出現次數：4
# 分類「醫療保健」出現次數：2
# 分類「影視偶像」出現次數：2
# 分類「語言學習」出現次數：2
# 分類「國中小參考書」出現次數：2
# 分類「飲食」出現次數：1
# 分類「限制級商品（需登入）」出現次數：1
# 分類「自然科普」出現次數：1
# 分類「藝術設計」出現次數：1
# 分類「宗教命理」出現次數：1

# %%
import pandas as pd
from datetime import datetime
import csv

# 讀取 static.csv（你的爬蟲輸出）
df = pd.read_csv("static.csv")

# 統計分類出現次數
category_count = df["分類"].value_counts().sort_values(ascending=False)

# 取得當前時間
now = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# 組合一列：時間 + Top 分類(次數)
row = [now] + [f"{cat}({count})" for cat, count in category_count.items()]

# 檢查欄位長度是否要更新（避免欄位不足）
csv_file = "category_log.csv"
try:
    with open(csv_file, newline='', encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        header = next(reader)
except FileNotFoundError:
    header = ["時間"]
if len(row) > len(header):
    header = ["時間"] + [f"Top{i}" for i in range(1, len(row))]

# 寫入資料（附加）
with open(csv_file, "a", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f)
    # 如果是空檔案，補寫欄位
    if f.tell() == 0:
        writer.writerow(header)
    writer.writerow(row)

print("✅ 已從 static.csv 統計分類並寫入 category_log.csv")
# Out:
# ✅ 已從 static.csv 統計分類並寫入 category_log.csv

# %%
import requests
import csv
import time
import random

# 自訂搜尋關鍵字，例如可以改成 "python", "小說", "AI", "travel" 等等
query = "python"

# Google Books API 的查詢網址
url = f"https://www.googleapis.com/books/v1/volumes?q={query}&maxResults=20"

# 模擬人類行為，避免 API 請求過快被封
def safe_sleep():
    t = random.uniform(1, 3)
    print(f"⏳ 等待 {t:.2f} 秒...")
    time.sleep(t)

# 發送 API 請求
safe_sleep()
res = requests.get(url)

# 檢查回應是否正常
if res.status_code != 200:
    print("❌ 無法取得資料，HTTP 錯誤碼：", res.status_code)
    exit()

# 將 API 回應轉為 JSON 格式
data = res.json()

# 建立清單存放書籍資料
book_data = []

# 逐筆取出書籍資訊
for item in data.get("items", []):
    info = item.get("volumeInfo", {})
    title = info.get("title", "無標題")
    authors = ", ".join(info.get("authors", ["未知作者"]))
    categories = ", ".join(info.get("categories", ["未知分類"]))
    link = info.get("infoLink", "無連結")
    
    print(f"📘 書名: {title}")
    print(f"    作者: {authors}")
    print(f"    分類: {categories}")
    print(f"    連結: {link}")
    print()

    book_data.append([title, authors, categories, link])

# 將結果寫入 CSV 檔案
with open("api_books.csv", "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f)
    writer.writerow(["書名", "作者", "分類", "連結"])
    writer.writerows(book_data)

print("✅ API 書籍資料已成功寫入 api_books.csv")
# Out:
# ⏳ 等待 1.31 秒...
# 📘 書名: Learning Python
#     作者: Mark Lutz
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=1HxWGezDZcgC&dq=python&hl=&source=gbs_api
#
# 📘 書名: Python in a Nutshell
#     作者: Alex Martelli
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=JnR9hQA3SncC&dq=python&hl=&source=gbs_api
#
# 📘 書名: Python for Unix and Linux System Administration
#     作者: Noah Gift, Jeremy M. Jones
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=Y7RCCgjmowcC&dq=python&hl=&source=gbs_api
#
# 📘 書名: Python Power!
#     作者: Matthew A. Telles
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=754knV_fyf8C&dq=python&hl=&source=gbs_api
#
# 📘 書名: Beginning Python
#     作者: Magnus Lie Hetland
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=HMvf12TnJQIC&dq=python&hl=&source=gbs_api
#
# 📘 書名: Programming Python
#     作者: Mark Lutz
#     分類: Computers
#     連結: https://play.google.com/store/books/details?id=q8W3WQbNWmkC&source=gbs_api
#
# 📘 書名: Python Essential Reference
#     作者: David M. Beazley
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=kQom0WiUbZQC&dq=python&hl=&source=gbs_api
#
# 📘 書名: Python
#     作者: Chris Fehily
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=carqdIdfVlYC&dq=python&hl=&source=gbs_api
#
# 📘 書名: Python Cookbook
#     作者: Alex Martelli, David Ascher
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=yhfdQgq8JF4C&dq=python&hl=&source=gbs_api
#
# 📘 書名: Natural Language Processing with Python
#     作者: Steven Bird, Ewan Klein, Edward Loper
#     分類: Computers
#     連結: https://play.google.com/store/books/details?id=KGIbfiiP1i4C&source=gbs_api
#
# 📘 書名: 圖解Python語言學習
#     作者: 賴財慶
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=C-RdDwAAQBAJ&dq=python&hl=&source=gbs_api
#
# 📘 書名: Python Concurrency with asyncio
#     作者: Matthew Fowler
#     分類: Computers
#     連結: https://play.google.com/store/books/details?id=M9xdEAAAQBAJ&source=gbs_api
#
# 📘 書名: Beginning Python
#     作者: James Payne
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=elnHAgAAQBAJ&dq=python&hl=&source=gbs_api
#
# 📘 書名: Python風格徹底研究｜超詳實、好理解的Python必學主題(電子書)
#     作者: Jason C McDonald
#     分類: Computers
#     連結: https://play.google.com/store/books/details?id=idj9EAAAQBAJ&source=gbs_api
#
# 📘 書名: 【最新ITS認證第二版】Python零基礎入門班(含ITS Python國際認證模擬試題)(電子書)
#     作者: 鄧君如 總監製/文淵閣工作室 編著
#     分類: Computers
#     連結: https://play.google.com/store/books/details?id=gIA1EQAAQBAJ&source=gbs_api
#
# 📘 書名: 從零開始學Python程式設計(第三版修訂版)（適用Python 3.10以上）
#     作者: 李馨
#     分類: Computers
#     連結: https://play.google.com/store/books/details?id=2oDEEAAAQBAJ&source=gbs_api
#
# 📘 書名: Core Python Programming
#     作者: Wesley Chun
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=mh0bU6NXrBgC&dq=python&hl=&source=gbs_api
#
# 📘 書名: Python Programming in Context
#     作者: Bradley N. Miller, David L. Ranum, Julie Anderson
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=b-2oDwAAQBAJ&dq=python&hl=&source=gbs_api
#
# 📘 書名: Programming in Python 3
#     作者: Mark Summerfield
#     分類: Computers
#     連結: http://books.google.com.tw/books?id=flRFgvAU7N8C&dq=python&hl=&source=gbs_api
#
# 📘 書名: Python功力提升的樂趣｜寫出乾淨程式碼的最佳實務(電子書)
#     作者: Al Sweigart
#     分類: Computers
#     連結: https://play.google.com/store/books/details?id=8-E2EAAAQBAJ&source=gbs_api
#
# ✅ API 書籍資料已成功寫入 api_books.csv
